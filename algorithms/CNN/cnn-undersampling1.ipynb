# %%
import numpy as np
import pandas as pd

import os
#for dirname, _, filenames in os.walk('/kaggle/input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/train'):
 #   for filename in filenames:
  #      print(os.path.join(dirname, filename))
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import regularizers
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, ZeroPadding2D
from tensorflow.keras.layers import Concatenate
from tensorflow.keras.optimizers import Adam, SGD

# %%
import glob
Mild = glob.glob('/kaggle/input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/train/MildDemented/*.*')
Moderate = glob.glob('/kaggle/input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/train/ModerateDemented/*.*')
NonDemented = glob.glob('/kaggle/input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/train/NonDemented/*.*')
VeryMild = glob.glob('/kaggle/input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/train/VeryMildDemented/*.*')


data=[]
labels = []

for i in NonDemented:   
    image=tf.keras.preprocessing.image.load_img(i, target_size= (224,224),grayscale=False)
    image=np.array(image)
    data.append(image)
    labels.append(0)

for i in VeryMild:   
    image=tf.keras.preprocessing.image.load_img(i, target_size= (224,224),grayscale=False)
    image=np.array(image)
    data.append(image)
    labels.append(1)

for i in Mild:   
    image=tf.keras.preprocessing.image.load_img(i, target_size= (224,224),grayscale=False)
    image=np.array(image)
    data.append(image)
    labels.append(2)

for i in Moderate:   
    image=tf.keras.preprocessing.image.load_img(i, target_size= (224,224),grayscale=False)
    image=np.array(image)
    data.append(image)
    labels.append(3)

# %%
#import random
#Moderate_US = Moderate
#Mild_US = random.sample(Mild, 52)
#VeryMild_US = random.sample(VeryMild, 52)
#NonDemented_US = random.sample(NonDemented, 52)

# %%
import random
Moderate_US = Moderate
Mild_US = Mild[:52]
VeryMild_US = VeryMild[:52]
NonDemented_US = NonDemented[:52]

# %%
from PIL import Image

data1 =[]
labels1 = []

for i in NonDemented_US: 
    image=tf.keras.preprocessing.image.load_img(i,target_size= (224,224),grayscale=False)
    image=np.array(image)
    data1.append(image)
    labels1.append(0)
    
for i in VeryMild_US:   
    image=tf.keras.preprocessing.image.load_img(i,target_size= (224,224),grayscale=False)
    image=np.array(image)
    data1.append(image)
    labels1.append(1)

for i in Mild_US:   
    image=tf.keras.preprocessing.image.load_img(i,target_size= (224,224),grayscale=False)
    image=np.array(image)
    data1.append(image)
    labels1.append(2)

for i in Moderate_US:   
    image=tf.keras.preprocessing.image.load_img(i,target_size= (224,224),grayscale=False)
    image=np.array(image)
    data1.append(image)
    labels1.append(3)

# %%
import glob
Mild_test = glob.glob('/kaggle/input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/test/MildDemented/*.*')
Moderate_test = glob.glob('/kaggle/input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/test/ModerateDemented/*.*')
NonDemented_test = glob.glob('/kaggle/input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/test/NonDemented/*.*')
VeryMild_test = glob.glob('/kaggle/input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/test/VeryMildDemented/*.*')


data_test = []
labels_test  = []

for i in NonDemented_test:   
    image=tf.keras.preprocessing.image.load_img(i, target_size= (224,224),grayscale=False)
    image=np.array(image)
    data_test.append(image)
    labels_test.append(0)

for i in VeryMild_test:   
    image=tf.keras.preprocessing.image.load_img(i, target_size= (224,224),grayscale=False)
    image=np.array(image)
    data_test.append(image)
    labels_test.append(1)

for i in Mild_test:   
    image=tf.keras.preprocessing.image.load_img(i, target_size= (224,224),grayscale=False)
    image=np.array(image)
    data_test.append(image)
    labels_test.append(2)

for i in Moderate_test:   
    image=tf.keras.preprocessing.image.load_img(i, target_size= (224,224),grayscale=False)
    image=np.array(image)
    data_test.append(image)
    labels_test.append(3)

# %%
#import random
#Moderate_US_test = Moderate_test
#Mild_US_test = random.sample(Mild_test, 12)
#VeryMild_US_test = random.sample(VeryMild_test, 12)
#NonDemented_US_test = random.sample(NonDemented_test, 12)

# %%
#data_test1 = []
#labels_test1  = []

#for i in NonDemented_US_test:   
 #   image=tf.keras.preprocessing.image.load_img(i, target_size= (224,224),color_mode='rgb')
  #  image=np.array(image)
   # data_test1.append(image)
    #labels_test1.append(0)

#for i in VeryMild_US_test:   
 #   image=tf.keras.preprocessing.image.load_img(i, target_size= (224,224),color_mode='rgb')
  #  image=np.array(image)
   # data_test1.append(image)
    #labels_test1.append(1)

#for i in Mild_US_test:   
 #   image=tf.keras.preprocessing.image.load_img(i, target_size= (224,224),color_mode='rgb')
  #  image=np.array(image)
   # data_test1.append(image)
    #labels_test1.append(2)

#for i in Moderate_US_test:   
 #   image=tf.keras.preprocessing.image.load_img(i, target_size= (224,224),color_mode='rgb')
  #  image=np.array(image)
   # data_test1.append(image)
    #labels_test1.append(3)

# %%
data1 = np.array(data1)
labels1 = np.array(labels1)

data_test = np.array(data_test)
labels_test = np.array(labels_test)

# %%
#print(data1.shape)
#print(labels1.shape)

#print(data_test.shape)
#print(labels_test.shape)

# %%
#import matplotlib.pyplot as plt
#image_test = data1[1]
#plt.imshow(image_test)
#plt.show()

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
#data1 = np.expand_dims(data1, axis=-1)  
datagen = ImageDataGenerator(rescale=1./255,
                            rotation_range=45,
                            width_shift_range=.15,
                            height_shift_range=.15,
                            horizontal_flip=False)

train_data_gen = datagen.flow(
    x=data1,
    y=labels1
)

# %%
test_data_gen = datagen.flow(
    x=data_test,
    y=labels_test
)

# %%
from keras.utils import to_categorical

train_data_gen.y = to_categorical(train_data_gen.y, num_classes=4)
test_data_gen.y = to_categorical(test_data_gen.y, num_classes=4)

# %%
#print(test_data_gen.y)

# %%
#y = data1.shape
#print(y)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# %% [markdown]
# CNN

# %%
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(4, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 111, 111, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 86528)             0
#
#  dense (Dense)               (None, 128)               11075712
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 11,169,476
# Trainable params: 11,169,476
# Non-trainable params: 0
# _________________________________________________________________

# %%
#def f1_score(y_true, y_pred): #taken from old keras source code
 #   true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
  #  possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
   # predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    #precision = true_positives / (predicted_positives + K.epsilon())
    #recall = true_positives / (possible_positives + K.epsilon())
    #f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    #return f1_val

# %%
import keras
import tensorflow_addons as tfa
METRICS = [keras.metrics.CategoricalAccuracy(name='accuracy'),
           keras.metrics.Precision(name='precision'),
           keras.metrics.Recall(name='recall'),
           keras.metrics.AUC(name='auc'),
           tfa.metrics.F1Score(num_classes=4),
           #tfa.metrics.MultiLabelConfusionMatrix(num_classes=4, name='confusion_matrix')
          ]
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
predictions_list = []

# %%
#model.compile(optimizer=tf.keras.optimizers.Adam(
 #   learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07, amsgrad=False,
  #  name='Adam',), loss='categorical_crossentropy',metrics=METRICS)
#history = model.fit(test_data_gen.x, test_data_gen.y, batch_size=16, epochs=5, validation_data=(test_data_gen.x, test_data_gen.y))

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=METRICS)

# Train the model with the metrics callback
history = model.fit(train_data_gen.x, train_data_gen.y, batch_size=16, epochs=37, validation_data=(test_data_gen.x, test_data_gen.y))
# Out:
# Epoch 1/30
# 7/7 [==============================] - 24s 4s/step - loss: 252.7216 - accuracy: 0.2212 - precision: 0.2233 - recall: 0.2212 - auc: 0.4799 - f1_score: 0.2120 - val_loss: 2.1472 - val_accuracy: 0.3495 - val_precision: 0.3448 - val_recall: 0.3127 - val_auc: 0.5138 - val_f1_score: 0.1488
# Epoch 2/30
# 7/7 [==============================] - 29s 5s/step - loss: 1.6941 - accuracy: 0.2933 - precision: 0.2807 - recall: 0.0769 - auc: 0.5388 - f1_score: 0.2919 - val_loss: 1.3754 - val_accuracy: 0.4480 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5942 - val_f1_score: 0.1971
# Epoch 3/30
# 7/7 [==============================] - 22s 3s/step - loss: 1.3617 - accuracy: 0.4231 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6441 - f1_score: 0.4225 - val_loss: 1.3923 - val_accuracy: 0.3096 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5031 - val_f1_score: 0.2086
# Epoch 4/30
# 7/7 [==============================] - 29s 5s/step - loss: 1.3554 - accuracy: 0.3029 - precision: 0.5000 - recall: 0.0048 - auc: 0.6060 - f1_score: 0.3001 - val_loss: 1.3226 - val_accuracy: 0.3628 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6308 - val_f1_score: 0.2035
# Epoch 5/30
# 7/7 [==============================] - 21s 3s/step - loss: 1.2167 - accuracy: 0.4615 - precision: 0.7000 - recall: 0.0673 - auc: 0.7466 - f1_score: 0.4558 - val_loss: 1.2471 - val_accuracy: 0.3643 - val_precision: 0.4282 - val_recall: 0.1353 - val_auc: 0.6680 - val_f1_score: 0.1670
# Epoch 6/30
# 7/7 [==============================] - 21s 3s/step - loss: 1.0094 - accuracy: 0.6298 - precision: 0.8058 - recall: 0.3990 - auc: 0.8289 - f1_score: 0.6234 - val_loss: 1.2578 - val_accuracy: 0.3237 - val_precision: 0.4615 - val_recall: 0.0141 - val_auc: 0.6462 - val_f1_score: 0.2532
# Epoch 7/30
# 7/7 [==============================] - 22s 3s/step - loss: 0.9390 - accuracy: 0.6538 - precision: 0.7600 - recall: 0.3654 - auc: 0.8613 - f1_score: 0.6541 - val_loss: 1.2535 - val_accuracy: 0.3557 - val_precision: 0.3817 - val_recall: 0.1665 - val_auc: 0.6710 - val_f1_score: 0.2324
# Epoch 8/30
# 7/7 [==============================] - 29s 5s/step - loss: 0.6950 - accuracy: 0.7644 - precision: 0.8121 - recall: 0.6442 - auc: 0.9209 - f1_score: 0.7643 - val_loss: 1.1803 - val_accuracy: 0.4652 - val_precision: 0.4597 - val_recall: 0.2228 - val_auc: 0.7398 - val_f1_score: 0.2901
# Epoch 9/30
# 7/7 [==============================] - 22s 3s/step - loss: 1.0145 - accuracy: 0.6058 - precision: 0.6385 - recall: 0.3990 - auc: 0.8155 - f1_score: 0.6031 - val_loss: 1.2983 - val_accuracy: 0.3471 - val_precision: 0.3655 - val_recall: 0.1837 - val_auc: 0.6708 - val_f1_score: 0.1879
# Epoch 10/30
# 7/7 [==============================] - 22s 3s/step - loss: 0.9269 - accuracy: 0.6875 - precision: 0.7647 - recall: 0.3125 - auc: 0.8822 - f1_score: 0.6844 - val_loss: 1.2785 - val_accuracy: 0.3597 - val_precision: 0.3636 - val_recall: 0.2189 - val_auc: 0.6949 - val_f1_score: 0.2467
# Epoch 11/30
# 7/7 [==============================] - 21s 3s/step - loss: 0.7030 - accuracy: 0.7404 - precision: 0.8378 - recall: 0.5962 - auc: 0.9246 - f1_score: 0.7396 - val_loss: 1.4642 - val_accuracy: 0.3651 - val_precision: 0.3641 - val_recall: 0.2838 - val_auc: 0.6864 - val_f1_score: 0.3234
# Epoch 12/30
# 7/7 [==============================] - 21s 3s/step - loss: 0.5282 - accuracy: 0.8221 - precision: 0.8779 - recall: 0.7260 - auc: 0.9570 - f1_score: 0.8215 - val_loss: 1.4352 - val_accuracy: 0.3792 - val_precision: 0.3807 - val_recall: 0.2995 - val_auc: 0.6940 - val_f1_score: 0.3150
# Epoch 13/30
# 7/7 [==============================] - 29s 5s/step - loss: 0.3803 - accuracy: 0.8846 - precision: 0.9348 - recall: 0.8269 - auc: 0.9806 - f1_score: 0.8835 - val_loss: 1.4276 - val_accuracy: 0.4073 - val_precision: 0.4125 - val_recall: 0.3190 - val_auc: 0.7035 - val_f1_score: 0.3933
# Epoch 14/30
# 7/7 [==============================] - 22s 3s/step - loss: 0.3213 - accuracy: 0.8702 - precision: 0.8945 - recall: 0.8558 - auc: 0.9823 - f1_score: 0.8700 - val_loss: 1.6577 - val_accuracy: 0.4848 - val_precision: 0.4911 - val_recall: 0.4738 - val_auc: 0.7724 - val_f1_score: 0.4141
# Epoch 15/30
# 7/7 [==============================] - 29s 5s/step - loss: 0.2408 - accuracy: 0.9087 - precision: 0.9130 - recall: 0.9087 - auc: 0.9888 - f1_score: 0.9083 - val_loss: 1.6628 - val_accuracy: 0.4378 - val_precision: 0.4470 - val_recall: 0.3987 - val_auc: 0.7117 - val_f1_score: 0.3600
# Epoch 16/30
# 7/7 [==============================] - 22s 3s/step - loss: 0.2142 - accuracy: 0.9135 - precision: 0.9400 - recall: 0.9038 - auc: 0.9920 - f1_score: 0.9141 - val_loss: 1.7111 - val_accuracy: 0.3401 - val_precision: 0.3603 - val_recall: 0.2682 - val_auc: 0.6247 - val_f1_score: 0.2848
# Epoch 17/30
# 7/7 [==============================] - 22s 3s/step - loss: 0.3317 - accuracy: 0.8990 - precision: 0.9158 - recall: 0.8365 - auc: 0.9849 - f1_score: 0.8977 - val_loss: 2.3618 - val_accuracy: 0.2995 - val_precision: 0.3019 - val_recall: 0.2729 - val_auc: 0.6015 - val_f1_score: 0.2729
# Epoch 18/30
# 7/7 [==============================] - 29s 5s/step - loss: 0.3319 - accuracy: 0.8702 - precision: 0.8995 - recall: 0.8606 - auc: 0.9800 - f1_score: 0.8715 - val_loss: 1.8060 - val_accuracy: 0.4105 - val_precision: 0.4166 - val_recall: 0.3690 - val_auc: 0.6887 - val_f1_score: 0.3737
# Epoch 19/30
# 7/7 [==============================] - 22s 3s/step - loss: 0.1548 - accuracy: 0.9423 - precision: 0.9554 - recall: 0.9279 - auc: 0.9966 - f1_score: 0.9421 - val_loss: 1.6674 - val_accuracy: 0.4558 - val_precision: 0.4647 - val_recall: 0.4120 - val_auc: 0.7259 - val_f1_score: 0.3920
# Epoch 20/30
# 7/7 [==============================] - 22s 3s/step - loss: 0.1146 - accuracy: 0.9615 - precision: 0.9706 - recall: 0.9519 - auc: 0.9984 - f1_score: 0.9614 - val_loss: 1.8576 - val_accuracy: 0.4371 - val_precision: 0.4479 - val_recall: 0.4034 - val_auc: 0.7124 - val_f1_score: 0.4181
# Epoch 21/30
# 7/7 [==============================] - 29s 5s/step - loss: 0.1134 - accuracy: 0.9471 - precision: 0.9471 - recall: 0.9471 - auc: 0.9979 - f1_score: 0.9473 - val_loss: 1.9187 - val_accuracy: 0.4504 - val_precision: 0.4513 - val_recall: 0.4277 - val_auc: 0.7266 - val_f1_score: 0.3721
# Epoch 22/30
# 7/7 [==============================] - 22s 3s/step - loss: 0.0788 - accuracy: 0.9760 - precision: 0.9805 - recall: 0.9663 - auc: 0.9996 - f1_score: 0.9760 - val_loss: 2.4697 - val_accuracy: 0.4277 - val_precision: 0.4331 - val_recall: 0.4175 - val_auc: 0.6938 - val_f1_score: 0.3648
# Epoch 23/30
# 7/7 [==============================] - 29s 5s/step - loss: 0.0670 - accuracy: 0.9904 - precision: 0.9903 - recall: 0.9856 - auc: 0.9999 - f1_score: 0.9904 - val_loss: 1.9231 - val_accuracy: 0.4316 - val_precision: 0.4454 - val_recall: 0.4113 - val_auc: 0.7107 - val_f1_score: 0.3831
# Epoch 24/30
# 7/7 [==============================] - 29s 5s/step - loss: 0.0477 - accuracy: 0.9952 - precision: 0.9952 - recall: 0.9952 - auc: 0.9998 - f1_score: 0.9952 - val_loss: 2.4889 - val_accuracy: 0.4253 - val_precision: 0.4257 - val_recall: 0.4073 - val_auc: 0.6977 - val_f1_score: 0.3965
# Epoch 25/30
# 7/7 [==============================] - 29s 5s/step - loss: 0.0758 - accuracy: 0.9808 - precision: 0.9854 - recall: 0.9760 - auc: 0.9988 - f1_score: 0.9808 - val_loss: 1.7892 - val_accuracy: 0.4582 - val_precision: 0.4668 - val_recall: 0.4347 - val_auc: 0.7378 - val_f1_score: 0.4032
# Epoch 26/30
# 7/7 [==============================] - 30s 5s/step - loss: 0.0731 - accuracy: 0.9712 - precision: 0.9756 - recall: 0.9615 - auc: 0.9992 - f1_score: 0.9711 - val_loss: 1.9570 - val_accuracy: 0.4097 - val_precision: 0.4140 - val_recall: 0.3784 - val_auc: 0.7003 - val_f1_score: 0.3683
# Epoch 27/30
# 7/7 [==============================] - 29s 5s/step - loss: 0.0935 - accuracy: 0.9808 - precision: 0.9854 - recall: 0.9712 - auc: 0.9994 - f1_score: 0.9808 - val_loss: 2.9854 - val_accuracy: 0.3862 - val_precision: 0.3888 - val_recall: 0.3745 - val_auc: 0.6523 - val_f1_score: 0.3531
# Epoch 28/30
# 7/7 [==============================] - 29s 5s/step - loss: 0.1896 - accuracy: 0.9519 - precision: 0.9515 - recall: 0.9423 - auc: 0.9923 - f1_score: 0.9517 - val_loss: 2.3634 - val_accuracy: 0.3518 - val_precision: 0.3647 - val_recall: 0.3245 - val_auc: 0.6229 - val_f1_score: 0.2916
# Epoch 29/30
# 7/7 [==============================] - 29s 5s/step - loss: 0.0995 - accuracy: 0.9712 - precision: 0.9757 - recall: 0.9663 - auc: 0.9983 - f1_score: 0.9711 - val_loss: 2.3878 - val_accuracy: 0.4027 - val_precision: 0.4025 - val_recall: 0.3792 - val_auc: 0.6693 - val_f1_score: 0.3990
# Epoch 30/30
# 7/7 [==============================] - 22s 3s/step - loss: 0.0736 - accuracy: 0.9663 - precision: 0.9709 - recall: 0.9615 - auc: 0.9992 - f1_score: 0.9663 - val_loss: 2.2934 - val_accuracy: 0.4480 - val_precision: 0.4552 - val_recall: 0.4332 - val_auc: 0.7123 - val_f1_score: 0.4115

# %%
import seaborn as sns
from keras.callbacks import Callback
from sklearn.metrics import classification_report, confusion_matrix
#final_predictions = np.argmax(model.predict(test_data_gen.x), axis=1)
true_labels = np.argmax(test_data_gen.y, axis=1)

final_predictions = np.argmax(model.predict(test_data_gen.x), axis=1)
final_predictions_onehot = to_categorical(final_predictions, num_classes=4)

# Compute the confusion matrix
final_cm = confusion_matrix(test_data_gen.y.argmax(axis=1), final_predictions_onehot.argmax(axis=1))

# Display the confusion matrix
print("\nFinal Confusion Matrix:")
print(final_cm)

# Visualize the confusion matrix using seaborn
#plt.figure(figsize=(8, 6))
#sns.heatmap(final_cm, annot=True, fmt="d", cmap="Blues", xticklabels=[f'Class {i}' for i in range(metrics_callback.num_classes)], yticklabels=[f'Class {i}' for i in range(metrics_callback.num_classes)])
#plt.xlabel('Predicted')
#plt.ylabel('True')
#plt.title('Final Confusion Matrix')
#plt.show()

# %%
results = model.evaluate(test_data_gen.x, test_data_gen.y)
print("Test Accuracy:", results[1])

# %%
results = model.evaluate(test_data_gen.x, test_data_gen.y)
print("Test Loss:", results[0])
print("Test Accuracy:", results[1])

# %%
import seaborn as sns
from keras.callbacks import Callback
from sklearn.metrics import confusion_matrix
from keras.utils import to_categorical

# Assuming final_predictions and test_data_gen.y are numpy arrays
all_predictions = max(model.predict(test_data_gen.x))
#max(model.predict(img_data)[0])

# Convert one-hot encoded true labels back to class indices
true_labels = np.argmax(test_data_gen.y, axis=1)

# Compute the confusion matrix
final_cm = confusion_matrix(true_labels, np.argmax(all_predictions, axis=1))

# Display the confusion matrix
print("\nFinal Confusion Matrix:")
print(final_cm)

# Visualize the confusion matrix using seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(final_cm, annot=True, fmt="d", cmap="Blues", xticklabels=[f'Class {i}' for i in range(4)], yticklabels=[f'Class {i}' for i in range(4)])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Final Confusion Matrix')
plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(test_data_gen.y.argmax(axis=1), final_predictions_onehot.argmax(axis=1)))

# %%
print(final_predictions )

# %%
print(test_data_gen.y)

# %%
model.save('my_modelU7.h5')

# %%
print(/kaggle/input/mlllkkk/my_modelU2.h5)
